# %%
square = lambda x: x**2

# %%
square(5)
# Out:
# 25

# %%
add = lambda x,y: x+y

# %%
add(12,25)
# Out:
# 37

# %%
avg = lambda a,b,c: (a+b+c)/3

# %%
avg(25,35,30)
# Out:
# 30.0

# %%
percentage = lambda a,b,c,d: f"{(a+b+c+d) * 0.25}%"

# %%
percentage(85,98,99,79)
# Out:
# '90.25%'

# %%
greater = lambda a, b: a if a > b else b

# %%
greater(12,78)
# Out:
# 78

# %%
numbers = [1, 2, 3, 4, 5]
result = []

for num in numbers:
    result.append(num ** 2)

result
# Out:
# [1, 4, 9, 16, 25]

# %%
is_even = lambda x: "even" if x % 2 == 0 else "odd"

# %%
is_even(6)
# Out:
# 'even'

# %%
numbers = [1, 2, 3, 4, 5, 6]
result = list(map(square, numbers))

result
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
numbers = [1, 2, 3, 4, 5, 6]
result = list(map(lambda x: x* 2, numbers))
result
# Out:
# [2, 4, 6, 8, 10, 12]

# %%
names = ["manish","rahul","amit"]
result = list(map(lambda a: a.upper(), names))
result
# Out:
# ['MANISH', 'RAHUL', 'AMIT']

# %%
names = ["APPLE","MANGO","BANANA"]
result = list(map(lambda a: a.lower(), names))
result
# Out:
# ['apple', 'mango', 'banana']

# %%
words = ["Python","Java","Flutter"]
result = list(map(lambda a: len(a), words))
result
# Out:
# [6, 4, 7]

# %%
numbers = [1,2,3,4]
result = list(map(lambda a: a+10, numbers))
result
# Out:
# [11, 12, 13, 14]

# %%
numbers = [2,4,6]
result = list(map(lambda a: a * 5, numbers))
result
# Out:
# [10, 20, 30]

# %%
numbers = [4,9,16,25]
result = list(map(lambda x: x ** 0.5, numbers))
result
# Out:
# [2.0, 3.0, 4.0, 5.0]

# %%
words = ["python","java","flutter"]
result = list(map(lambda x: x[::-1], words))
result
# Out:
# ['nohtyp', 'avaj', 'rettulf']

# %%
names = ["  Manish  "," Rahul "," Amit "]
result = list(map(lambda x: x.replace(" ", ""), names))
result
# Out:
# ['Manish', 'Rahul', 'Amit']

# %%
temps = [0,20,30,40]
convert = lambda c: (c * 9 / 5) + 32
result = list(map(convert, temps))
result
# Out:
# [32.0, 68.0, 86.0, 104.0]

# %%
sides = [2,4,6,8]
area = lambda x: x**2
result = list(map(area, sides))
result
# Out:
# [4, 16, 36, 64]

# %%
a = [1,2,3]
b = [4,5,6]
add = lambda a, b: a + b
result = list(map(add, a, b))
result
# Out:
# [5, 7, 9]

# %%
a = [2,3,4]
b = [5,6,7]

multiply = lambda x, y: x * y
result = list(map(multiply, a, b))
result
# Out:
# [10, 18, 28]

# %%
first = ["Manish","Rahul","Amit"]
last = ["Agrahari","Sharma","Kumar"]

concat = lambda a, b: a + " " + b
result = list(map(concat, first, last))
result
# Out:
# ['Manish Agrahari', 'Rahul Sharma', 'Amit Kumar']

# %%
def cube(num):
    return num ** 3

numbers = [1, 2, 3, 4, 5]
result = type(map(cube, numbers))
result
# Out:
# map

# %%
numbers = [1,2,3,4,5,6]

result = list(filter(lambda x: x % 2 == 0, numbers))

result
# Out:
# [2, 4, 6]

# %%
numbers = [10,25,60,80,45,90]

result = list(filter(lambda x: x > 50, numbers))
result
# Out:
# [60, 80, 90]

# %%
words = ["Python","","Java","","Flutter",""]

result = list(filter(lambda a: len(a) > 0, words))
result
# Out:
# ['Python', 'Java', 'Flutter']

# %%
names = ["Ram","Manish","Rahul","AI","Flutter"]
result = list(filter(lambda a: len(a) > 5, names))
result
# Out:
# ['Manish', 'Flutter']

# %%
words = ["Python","Java","Kotlin","Flutter","Rust"]
result = list(filter(lambda a: a[-1] == "n", words))
result
# Out:
# ['Python', 'Kotlin']

# %%
def square(n):
    return n ** 2

map(square, numbers)
