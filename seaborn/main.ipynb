# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('Student Depression Dataset.csv')

# %%
sales_df = pd.read_csv('Chocolate Sales.csv')

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
sales_df.head()
# Out:
#      Sales Person    Country              Product        Date      Amount  \
# 0  Jehu Rudeforth         UK      Mint Chip Choco  04/01/2022   $5,320.00
# 1     Van Tuxwell      India        85% Dark Bars  01/08/2022   $7,896.00
# 2    Gigi Bohling      India  Peanut Butter Cubes  07/07/2022   $4,501.00
# 3    Jan Morforth  Australia  Peanut Butter Cubes  27/04/2022  $12,726.00
# 4  Jehu Rudeforth         UK  Peanut Butter Cubes  24/02/2022  $13,685.00
#
#    Boxes Shipped
# 0            180
# 1             94
# 2             91
# 3            342
# 4            184

# %% [markdown]
# ## Axis level fn -> Line Plot

# %%
sns.lineplot(data=df, x='Age', y='CGPA', hue='Gender')
plt.show()

# %%
sns.relplot(data=df, x='Age', y='CGPA', kind='line', hue='Gender', style='Dietary Habits')

# %%
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(data=tips, x='day', y='total_bill', hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.relplot(data=tips, x='day', y='total_bill', hue='sex',style='smoker', kind='line')

# %%
sns.lineplot(data=tips, x='day', y='total_bill', hue='smoker', style='time')
plt.plot()
# Out:
# []

# %%
gap = px.data.gapminder()

# %%
gap.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gap.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   str
#  1   continent  1704 non-null   str
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   str
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), str(3)
# memory usage: 135.3 KB

# %%
gap['continent'].unique()
# Out:
# <ArrowStringArray>
# ['Asia', 'Europe', 'Africa', 'Americas', 'Oceania']
# Length: 5, dtype: str

# %%
sns.lineplot(data=gap, x='year', y='lifeExp', hue='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
gap['country'].unique()
# Out:
# <ArrowStringArray>
# [       'Afghanistan',            'Albania',            'Algeria',
#              'Angola',          'Argentina',          'Australia',
#             'Austria',            'Bahrain',         'Bangladesh',
#             'Belgium',
#  ...
#              'Uganda',     'United Kingdom',      'United States',
#             'Uruguay',          'Venezuela',            'Vietnam',
#  'West Bank and Gaza',        'Yemen, Rep.',             'Zambia',
#            'Zimbabwe']
# Length: 142, dtype: str

# %%
data = gap[gap['country'].isin(['India', 'Brazil', 'Germany'])]
data
# Out:
#      country continent  year  lifeExp         pop     gdpPercap iso_alpha  \
# 168   Brazil  Americas  1952   50.917    56602560   2108.944355       BRA
# 169   Brazil  Americas  1957   53.285    65551171   2487.365989       BRA
# 170   Brazil  Americas  1962   55.665    76039390   3336.585802       BRA
# 171   Brazil  Americas  1967   57.632    88049823   3429.864357       BRA
# 172   Brazil  Americas  1972   59.504   100840058   4985.711467       BRA
# 173   Brazil  Americas  1977   61.489   114313951   6660.118654       BRA
# 174   Brazil  Americas  1982   63.336   128962939   7030.835878       BRA
# 175   Brazil  Americas  1987   65.205   142938076   7807.095818       BRA
# 176   Brazil  Americas  1992   67.057   155975974   6950.283021       BRA
# 177   Brazil  Americas  1997   69.388   168546719   7957.980824       BRA
# 178   Brazil  Americas  2002   71.006   179914212   8131.212843       BRA
# 179   Brazil  Americas  2007   72.390   190010647   9065.800825       BRA
# ...

# %%
sns.lineplot(data=data, x='year', y='lifeExp', hue='continent', size='continent')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
sns.scatterplot(data=df, x='Age', y='CGPA')
# Out:
# <Axes: xlabel='Age', ylabel='CGPA'>

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip', hue='sex', size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips, x='total_bill', y='tip', hue='sex', size='size')

# %%
sns.scatterplot(data=gap, x='lifeExp', y='pop', hue='continent')
# Out:
# <Axes: xlabel='lifeExp', ylabel='pop'>

# %%
sns.relplot(data=gap, x='lifeExp', y='pop', hue='continent')

# %%
sns.relplot(data=tips, x='total_bill', y='tip', col='sex', row='smoker', kind='scatter')
plt.plot()
# Out:
# []

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='str')

# %%
sns.relplot(data=gap, x='lifeExp', y='pop', kind='scatter', col='year', col_wrap=3)
plt.plot()
# Out:
# []

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
sns.histplot(data=df, x='Age', hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(data=df, x='Age', hue='Gender', col='Gender')

# %%
sns.histplot(data=tips, x='total_bill', hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=gap, x='lifeExp', hue='continent', element='step')
# Out:
# <Axes: xlabel='lifeExp', ylabel='Count'>

# %%
sns.displot(data=gap, x='lifeExp', col='continent', col_wrap=3)

# %%
sns.kdeplot(data=df, x='Age', fill=True, hue='Gender')
plt.plot()
# Out:
# []

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=gap, x='lifeExp', kind='kde', fill=True)

# %%
sns.rugplot(data=gap, x='lifeExp', hue='continent')
# Out:
# <Axes: xlabel='lifeExp'>

# %%
sns.kdeplot(data=tips, x='total_bill', hue='sex')
sns.rugplot(data=tips, x='total_bill', hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.histplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
dt = gap.pivot(index='country', columns='year', values='lifeExp')
dt
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# ...

# %%
plt.figure(figsize=(25, 35))
sns.heatmap(data=dt)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
asia_dt = gap[gap['continent'] == 'Asia'].pivot(index='country', columns='year', values='lifeExp')

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(data=asia_dt, annot=True, cmap='viridis', linewidths=0.5)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
iris = px.data.iris()
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
sns.clustermap(data=iris.iloc[:, [0,1,2,3]])

# %%
sns.barplot(data=gap, x='continent', y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
sns.barplot(data=gap, x='continent', y='gdpPercap')
# Out:
# <Axes: xlabel='continent', ylabel='gdpPercap'>

# %%
sns.barplot(data=df, x='Dietary Habits', y='Depression')
# Out:
# <Axes: xlabel='Dietary Habits', ylabel='Depression'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(data=tips, x='sex', y='total_bill', hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(data=tips, x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=tips, x='time')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(data=tips, x='size')
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
sns.countplot(data=gap, x='continent')
# Out:
# <Axes: xlabel='continent', ylabel='count'>

# %%
sns.boxplot(data=gap, x='continent', y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
sns.boxplot(data=tips, x='sex', y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.violinplot(data=tips, x='sex', y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.violinplot(data=gap, x='continent', y='lifeExp')
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
sns.swarmplot(data=sales_df, x='Country', y='Boxes Shipped')
# Out:
# c:\Users\ManishAgrahari\Desktop\my_learning\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 53.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ManishAgrahari\Desktop\my_learning\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 54.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ManishAgrahari\Desktop\my_learning\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 55.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\ManishAgrahari\Desktop\my_learning\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 51.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
sns.regplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(data=gap, x='lifeExp', y='gdpPercap')
# Out:
# <Axes: xlabel='lifeExp', ylabel='gdpPercap'>

# %%
sns.jointplot(data=tips, x='total_bill', y='tip')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='reg')

# %%
sns.pairplot(data=df)

# %%
sns.pairplot(data=tips)

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=sales_df)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
