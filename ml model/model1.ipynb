# %% [markdown]
# # Step 1 Framing the Machine learning Problem
#
# ## Predicting the price of International education based on city, course, fees, visa and all

# %% [markdown]
# # Step 2 Data Gathering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pd.read_csv('International_Education_Costs.csv')

# %% [markdown]
# # Step 3 Data Exploration , Data Cleaning and Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), str(5)
# memory usage: 135.6 KB

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...

# %%
df.isna().sum()
# Out:
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'City', 'University', 'Program', 'Level', 'Duration_Years',
#        'Tuition_USD', 'Living_Cost_Index', 'Rent_USD', 'Visa_Fee_USD',
#        'Insurance_USD', 'Exchange_Rate'],
#       dtype='str')

# %%
df['Duration_Years'].unique()
# Out:
# 7

# %%
for col in df.columns:
    print(f'{col} => {df[col].nunique()}')
# Out:
# Country => 71
# City => 556
# University => 622
# Program => 92
# Level => 3
# Duration_Years => 7
# Tuition_USD => 274
# Living_Cost_Index => 225
# Rent_USD => 67
# Visa_Fee_USD => 30
# Insurance_USD => 20
# Exchange_Rate => 65

# %%
df['Duration_Years'].value_counts()
# Out:
# Duration_Years
# 2.0    423
# 4.0    276
# 3.0    171
# 5.0     17
# 1.0     16
# 2.5      3
# 1.5      1
# Name: count, dtype: int64

# %%
for col in df.columns:
    print(f'{col} => {df[col].value_counts()}')

# %%
df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate
# count    907.000000     907.000000     907.000000
# mean     211.396913     700.077178     623.000695
# std      143.435740     320.374875    3801.746134
# min       40.000000     200.000000       0.150000
# 25%      100.000000     450.000000       0.920000
# 50%      160.000000     650.000000       1.350000
# ...

# %%
for col in df.columns:
    print(f'{col} => {df[col].dtypes}')
# Out:
# Country => str
# City => str
# University => str
# Program => str
# Level => str
# Duration_Years => float64
# Tuition_USD => int64
# Living_Cost_Index => float64
# Rent_USD => int64
# Visa_Fee_USD => int64
# Insurance_USD => int64
# Exchange_Rate => float64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    str
#  1   City               907 non-null    str
#  2   University         907 non-null    str
#  3   Program            907 non-null    str
#  4   Level              907 non-null    str
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), str(5)
# memory usage: 135.6 KB

# %%
df.shape
# Out:
# (907, 12)

# %%
df.size
# Out:
# 10884

# %%
df.dtypes
# Out:
# Country                  str
# City                     str
# University               str
# Program                  str
# Level                    str
# Duration_Years       float64
# Tuition_USD            int64
# Living_Cost_Index    float64
# Rent_USD               int64
# Visa_Fee_USD           int64
# Insurance_USD          int64
# Exchange_Rate        float64
# dtype: object

# %%
df['Country'].value_counts()
# Out:
# Country
# UK                93
# Australia         86
# USA               78
# Canada            76
# Germany           33
#                   ..
# Taiwan             1
# Czech Republic     1
# South Africa       1
# Nigeria            1
# Vietnam            1
# Name: count, Length: 71, dtype: int64

# %%
df['Program'].value_counts()
# Out:
# Program
# Computer Science           312
# Data Science                82
# Computer Engineering        71
# Software Engineering        57
# Artificial Intelligence     53
#                           ...
# Electronics                  1
# Electronic Engineering       1
# Digital Design               1
# Digital Business             1
# Data Systems                 1
# Name: count, Length: 92, dtype: int64

# %%
df['Level'].value_counts()
# Out:
# Level
# Master      451
# Bachelor    297
# PhD         159
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Step 4 Exploratory Data Analysis

# %%
top_country = df[df['Country'].isin(['UK', 'Australia', 'USA', 'Canada', 'Germany', 'France', 'South Korea', 'Switzerland'])]

# %%
sns.countplot(data=top_country, x='Country')
plt.xticks(rotation='vertical')
plt.show()

# %%
df['City'].value_counts()
# Out:
# City
# Singapore    18
# Melbourne    11
# Sydney       11
# London       10
# Canberra      8
#              ..
# Tabuk         1
# Shah Alam     1
# Makkah        1
# Nilai         1
# Al-Ahsa       1
# Name: count, Length: 556, dtype: int64

# %%
city = df[df['City'].isin(['Singapore', 'Melbourne', 'Sydney', 'London', 'Canberra'])]

# %%
sns.countplot(data=city, x='Level')
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
sns.countplot(data=df, x='Level')
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
df['Level'].value_counts()
# Out:
# Level
# Master      451
# Bachelor    297
# PhD         159
# Name: count, dtype: int64

# %%
d1 = df[df['Level'] == 'Master'].head(150)
d2 = df[df['Level'] == 'Bachelor'].head(150)
d3 = df[df['Level'] == 'PhD'].head(150)

# %%
d4 = pd.concat([d1, d2, d3])

# %%
sns.histplot(data=d4, x='Duration_Years')
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Count'>

# %%
sns.histplot(data=df, x='Tuition_USD')
# Out:
# <Axes: xlabel='Tuition_USD', ylabel='Count'>

# %%
sns.kdeplot(data=df, x='Rent_USD')
# Out:
# <Axes: xlabel='Rent_USD', ylabel='Density'>

# %%
sns.boxplot(data=df, y='Rent_USD')
# Out:
# <Axes: ylabel='Rent_USD'>

# %%
sns.barplot(data=top_country, x='Country', y='Tuition_USD')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(data=top_country, x='Country', y='Visa_Fee_USD')
plt.xticks(rotation=45)
plt.show()

# %%
university = df[df['University'].isin(['University of Washington', 'University of Melbourne', 'Stanford University', 'Australian National University', 'University of Sydney', 'Harvard University'])]

# %%
df['University'].value_counts()
# Out:
# University
# University of Washington          6
# University of Melbourne           5
# Stanford University               5
# Australian National University    5
# University of Sydney              5
#                                  ..
# University of Tabuk               1
# UiTM                              1
# Umm Al-Qura University            1
# USIM                              1
# King Faisal University            1
# Name: count, Length: 622, dtype: int64

# %%
sns.barplot(data=university, x='University', y='Tuition_USD')
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(data=university, x='University', y='Duration_Years')
plt.xticks(rotation=45)
plt.show()

# %%
sns.lineplot(data=university, x='University', y='Duration_Years')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
sns.scatterplot(data=df, x='Duration_Years', y='Tuition_USD')
# Out:
# <Axes: xlabel='Duration_Years', ylabel='Tuition_USD'>

# %%
sns.lineplot(data=university, x='University', y='Duration_Years')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# ## Step 5 Feature Engineering

# %%
df['Total_Cost'] = df['Rent_USD'] + df['Tuition_USD']

# %%
df = df[['Country','City','University','Program','Level','Duration_Years','Living_Cost_Index','Visa_Fee_USD','Insurance_USD','Total_Cost']]

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
le = LabelEncoder()

# %%
df['Country'] = le.fit_transform(df['Country'])

# %%
df['City'] = le.fit_transform(df['City'])

# %%
df['Program'] = le.fit_transform(df['Program'])

# %%
df['Level'] = le.fit_transform(df['Level'])

# %%
df['University'] = le.fit_transform(df['University'])

# %%
x = df.drop('Total_Cost', axis=1)
y = df['Total_Cost']

# %%
sc = StandardScaler()

# %%
x = sc.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 8659.427341273544

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_predict)
# Out:
# 130433373.64519891

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge
r = Ridge(alpha=0.1)

# %%
r.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
y_predict = r.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 8659.433012802261

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso

l = Lasso(alpha=0.01)

# %%
l.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.01)

# %%
y_predict = l.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 8659.427236248222

# %% [markdown]
# # ElasticNet

# %%
from sklearn.linear_model import ElasticNet

e = ElasticNet(alpha=0.01, l1_ratio=0.5)

# %%
e.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=0.01)

# %%
y_predict = e.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 8659.905824165275

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

tree  =DecisionTreeRegressor(max_depth=5)

# %%
tree.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_predict = tree.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 4136.742081363999

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_predict = rf.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 2691.550549450549

# %% [markdown]
# ## Ensemble Learning
# #### XGBoost
# #### AdaBoost
# #### CatBoost

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada = AdaBoostRegressor(n_estimators=100)

# %%
ada.fit(x_train, y_train)
# Out:
# AdaBoostRegressor(n_estimators=100)

# %%
y_predict = ada.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 5316.777417973163

# %%
# pip install xgboost and catboost for its usage

# %% [markdown]
# # K Neighours Regression -> Neighours Data points -> Neighours Prediction

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_predict = knn.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 5825.32967032967

# %% [markdown]
# # SVM Support Vector Machine --> Support Vector Regressor

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel='rbf')

# %%
svr.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_predict = svr.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 14308.751937241615

# %% [markdown]
# # Bagging Regressor -> Ensemble Leaning

# %%
from sklearn.ensemble import BaggingRegressor

# %%
bag = BaggingRegressor(n_estimators=100)

# %%
bag.fit(x_train, y_train)
# Out:
# BaggingRegressor(n_estimators=100)

# %%
y_predict = bag.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 2706.3565934065937

# %% [markdown]
# # Stacking Regreesor -> Ensmeble
# ## Combination of multiplemmodel of our own choice

# %%
from sklearn.ensemble import StackingRegressor, BaggingRegressor, RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
estimators = [('rf', RandomForestRegressor()), ('bag', BaggingRegressor())]

# %%
stack = StackingRegressor(estimators=estimators, final_estimator=DecisionTreeRegressor())

# %%
stack.fit(x_train, y_train)
# Out:
# StackingRegressor(estimators=[('rf', RandomForestRegressor()),
#                               ('bag', BaggingRegressor())],
#                   final_estimator=DecisionTreeRegressor())

# %%
y_predict = stack.predict(x_test)

# %%
mean_absolute_error(y_test, y_predict)
# Out:
# 4357.3626373626375
