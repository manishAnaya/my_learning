# %%
import pandas as pd

data = pd.read_csv("youtube_tech_channels_20251120_133753.csv")
data
# Out:
#                    channel_id                     channel_name  \
# 0    UCXuqSBlHAE6Xw-yeJA0Tunw                  Linus Tech Tips
# 1    UCWv7vMbMWH4-V0ZXdmDpPBA            Programming with Mosh
# 2    UChIZGfcnjHI0DG4nweWEduw                       TechSource
# 3    UC4SVo0Ue36XCfOyb5Lh1viQ                         Bro Code
# 4    UCVeW9qkBjo3zosnqUbG7CFw                     John Hammond
# ..                        ...                              ...
# 125  UCBKM3HATRILZyG9jGNJKGXQ       Software Engineering Daily
# 126  UCvckuc-3Sos1aUtSqCV_0xw          Georgia Web Development
# 127  UC4lM4hz_v5ixNjK54UwPEVw  Machine Learning and AI Academy
# 128  UCTnOFmMwZIi7jJYS_nAfeyQ               The Helpful Hacker
# 129  UCHd1qamEkVSlTWkEqIqJbEQ          Visual Computer Science
#
#                                            description  subscribers  \
# 0    Linus Tech Tips is a passionate team of "profe...     16600000
# 1    Hi! I'm Mosh 👋, a software engineer with over ...      4860000
# ...

# %%
df = pd.read_csv("youtube_tech_channels_20251120_133753.csv")
df
# Out:
#                    channel_id                     channel_name  \
# 0    UCXuqSBlHAE6Xw-yeJA0Tunw                  Linus Tech Tips
# 1    UCWv7vMbMWH4-V0ZXdmDpPBA            Programming with Mosh
# 2    UChIZGfcnjHI0DG4nweWEduw                       TechSource
# 3    UC4SVo0Ue36XCfOyb5Lh1viQ                         Bro Code
# 4    UCVeW9qkBjo3zosnqUbG7CFw                     John Hammond
# ..                        ...                              ...
# 125  UCBKM3HATRILZyG9jGNJKGXQ       Software Engineering Daily
# 126  UCvckuc-3Sos1aUtSqCV_0xw          Georgia Web Development
# 127  UC4lM4hz_v5ixNjK54UwPEVw  Machine Learning and AI Academy
# 128  UCTnOFmMwZIi7jJYS_nAfeyQ               The Helpful Hacker
# 129  UCHd1qamEkVSlTWkEqIqJbEQ          Visual Computer Science
#
#                                            description  subscribers  \
# 0    Linus Tech Tips is a passionate team of "profe...     16600000
# 1    Hi! I'm Mosh 👋, a software engineer with over ...      4860000
# ...

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.head()
# Out:
#                  channel_id           channel_name  \
# 0  UCXuqSBlHAE6Xw-yeJA0Tunw        Linus Tech Tips
# 1  UCWv7vMbMWH4-V0ZXdmDpPBA  Programming with Mosh
# 2  UChIZGfcnjHI0DG4nweWEduw             TechSource
# 3  UC4SVo0Ue36XCfOyb5Lh1viQ               Bro Code
# 4  UCVeW9qkBjo3zosnqUbG7CFw           John Hammond
#
#                                          description  subscribers  \
# 0  Linus Tech Tips is a passionate team of "profe...     16600000
# 1  Hi! I'm Mosh 👋, a software engineer with over ...      4860000
# 2  Join the Discord Server:\nhttps://discord.gg/T...      4010000
# 3                     Coding bootcamps HATE HIM! 🗿\n      2990000
# 4  Free Cybersecurity Education and Ethical Hacking.      2080000
#
#    total_views  total_videos                 created_date country  \
# 0   9092244390          6989         2008-11-25T00:46:52Z      CA
# 1    257598451           243         2014-10-07T00:40:53Z      US
# ...

# %%
df = pd.read_csv("youtube_tech_channels.csv")
print(df)
print(type(df))
print(df.ndim)
print(df.shape)
# Out:
#                  Channel
# 0          Tech With Tim
# 1  Programming with Mosh
# 2       freeCodeCamp.org
# 3          Corey Schafer
# 4         Traversy Media
# 5          CodeWithHarry
# 6           Apna College
# 7                Telusko
# 8             Krish Naik
# 9            Simplilearn
# <class 'pandas.DataFrame'>
# 2
# (10, 1)

# %%
series = df.squeeze("columns")
print(series)
print(type(series))
print(series.ndim)
print(series.shape)
# Out:
# 0            Tech With Tim
# 1    Programming with Mosh
# 2         freeCodeCamp.org
# 3            Corey Schafer
# 4           Traversy Media
# 5            CodeWithHarry
# 6             Apna College
# 7                  Telusko
# 8               Krish Naik
# 9              Simplilearn
# Name: Channel, dtype: str
# <class 'pandas.Series'>
# 1
# (10,)

# %%
dataframe = pd.read_csv("youtube_tech_channels_videos.csv", index_col="Youtuber Name").squeeze("columns")

print(dataframe)
print(type(dataframe))
# Out:
# Youtuber Name
# Tech With Tim             850
# Programming with Mosh     420
# freeCodeCamp.org         1800
# Corey Schafer             300
# Traversy Media           1200
# CodeWithHarry             950
# Apna College              700
# Telusko                   650
# Krish Naik                900
# Simplilearn              2500
# Name: Total Videos, dtype: int64
# <class 'pandas.Series'>

# %%
type(dataframe)
# Out:
# pandas.Series

# %%
dataframe.values
# Out:
# array([ 850,  420, 1800,  300, 1200,  950,  700,  650,  900, 2500])

# %%
dataframe.index
# Out:
# Index(['Tech With Tim', 'Programming with Mosh', 'freeCodeCamp.org',
#        'Corey Schafer', 'Traversy Media', 'CodeWithHarry', 'Apna College',
#        'Telusko', 'Krish Naik', 'Simplilearn'],
#       dtype='str', name='Youtuber Name')

# %%
dataframe.dtype
# Out:
# dtype('int64')

# %%
new_f = dataframe.astype('int32')

# %%
new_f.dtype
# Out:
# dtype('int32')

# %%
dataframe.size
# Out:
# 10

# %%
dataframe.shape
# Out:
# (10,)

# %%
dataframe.ndim
# Out:
# 1

# %%
dataframe
# Out:
# Youtuber Name
# Tech With Tim             850
# Programming with Mosh     420
# freeCodeCamp.org         1800
# Corey Schafer             300
# Traversy Media           1200
# CodeWithHarry             950
# Apna College              700
# Telusko                   650
# Krish Naik                900
# Simplilearn              2500
# Name: Total Videos, dtype: int64

# %%
df.head()
# Out:
#                  Channel
# 0          Tech With Tim
# 1  Programming with Mosh
# 2       freeCodeCamp.org
# 3          Corey Schafer
# 4         Traversy Media

# %%
dataframe.head()
# Out:
# Youtuber Name
# Tech With Tim             850
# Programming with Mosh     420
# freeCodeCamp.org         1800
# Corey Schafer             300
# Traversy Media           1200
# Name: Total Videos, dtype: int64

# %%
dataframe.is_unique
# Out:
# True

# %%
dataframe.name
# Out:
# 'Total Videos'

# %%
dataframe.tail(7)
# Out:
# Youtuber Name
# Corey Schafer      300
# Traversy Media    1200
# CodeWithHarry      950
# Apna College       700
# Telusko            650
# Krish Naik         900
# Simplilearn       2500
# Name: Total Videos, dtype: int64

# %%
dataframe.sample(3)
# Out:
# Youtuber Name
# Simplilearn      2500
# Apna College      700
# Tech With Tim     850
# Name: Total Videos, dtype: int64

# %%
dataframe.value_counts()
# Out:
# Total Videos
# 850     1
# 420     1
# 1800    1
# 300     1
# 1200    1
# 950     1
# 700     1
# 650     1
# 900     1
# 2500    1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                  Channel
# 0          Tech With Tim
# 1  Programming with Mosh
# 2       freeCodeCamp.org
# 3          Corey Schafer
# 4         Traversy Media

# %%
series = pd.Series(range(1, 11))

print(series.sample(3))
print(series.sample(3, random_state=42))
# Out:
# 0    1
# 8    9
# 4    5
# dtype: int64
# 8    9
# 1    2
# 5    6
# dtype: int64

# %%
series = pd.Series(
    ["A", "B", "A", "C", "B"]
)

print(series.unique())
# Out:
# <ArrowStringArray>
# ['A', 'B', 'C']
# Length: 3, dtype: str

# %%
series = pd.Series(
    ["A", "B", "A", "C", "B"]
)

print(series.nunique())
# Out:
# 3

# %%
series = pd.Series([1, 2, 3, 4])

print(series.is_unique)
print(series.is_monotonic_increasing)
print(series.is_monotonic_decreasing)
# Out:
# True
# True
# False

# %%
series = pd.Series([True, True, False])

print(series.all())
print(series.any())
# Out:
# False
# True

# %%
series = pd.Series([-10, -5, 3])

print(series.abs())
# Out:
# 0    10
# 1     5
# 2     3
# dtype: int64

# %%
series = pd.Series([10, 20, 30, 40])

print(series.between(20, 30))
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# dtype: bool

# %%
series = pd.Series([10, 20, 30, 40, 50])

print(series.clip(lower=20, upper=40))
# Out:
# 0    20
# 1    20
# 2    30
# 3    40
# 4    40
# dtype: int64

# %%
series = pd.Series([10, 20, 30, 40, 50])

print(series.quantile(0.5))
print(series.quantile(0.75))
print(series.quantile(0.25))
# Out:
# 30.0
# 40.0
# 20.0

# %%
len(dataframe)
# Out:
# 10

# %%
dataframe.size
# Out:
# 10

# %%
type(dataframe)
# Out:
# pandas.Series

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
len(df)
# Out:
# 10

# %%
dir(df)
# Out:
# ['Channel',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
dataframe
# Out:
# Youtuber Name
# Tech With Tim             850
# Programming with Mosh     420
# freeCodeCamp.org         1800
# Corey Schafer             300
# Traversy Media           1200
# CodeWithHarry             950
# Apna College              700
# Telusko                   650
# Krish Naik                900
# Simplilearn              2500
# Name: Total Videos, dtype: int64

# %%
sorted(dataframe)
# Out:
# [300, 420, 650, 700, 850, 900, 950, 1200, 1800, 2500]

# %%
dataframe.min()
# Out:
# np.int64(300)

# %%
min(dataframe)
# Out:
# 300

# %%
list(dataframe)
# Out:
# [850, 420, 1800, 300, 1200, 950, 700, 650, 900, 2500]

# %%
dict(dataframe)
# Out:
# {'Tech With Tim': np.int64(850),
#  'Programming with Mosh': np.int64(420),
#  'freeCodeCamp.org': np.int64(1800),
#  'Corey Schafer': np.int64(300),
#  'Traversy Media': np.int64(1200),
#  'CodeWithHarry': np.int64(950),
#  'Apna College': np.int64(700),
#  'Telusko': np.int64(650),
#  'Krish Naik': np.int64(900),
#  'Simplilearn': np.int64(2500)}

# %%
dict(df)
# Out:
# {'Channel': 0            Tech With Tim
#  1    Programming with Mosh
#  2         freeCodeCamp.org
#  3            Corey Schafer
#  4           Traversy Media
#  5            CodeWithHarry
#  6             Apna College
#  7                  Telusko
#  8               Krish Naik
#  9              Simplilearn
#  Name: Channel, dtype: str}

# %%
list((df['Channel']))
# Out:
# ['Tech With Tim',
#  'Programming with Mosh',
#  'freeCodeCamp.org',
#  'Corey Schafer',
#  'Traversy Media',
#  'CodeWithHarry',
#  'Apna College',
#  'Telusko',
#  'Krish Naik',
#  'Simplilearn']

# %%
dataframe
# Out:
# Youtuber Name
# Tech With Tim             850
# Programming with Mosh     420
# freeCodeCamp.org         1800
# Corey Schafer             300
# Traversy Media           1200
# CodeWithHarry             950
# Apna College              700
# Telusko                   650
# Krish Naik                900
# Simplilearn              2500
# Name: Total Videos, dtype: int64

# %%
"Apna College" in dataframe
# Out:
# True

# %%
for i in df['Channel']:
    print(i)
# Out:
# Tech With Tim
# Programming with Mosh
# freeCodeCamp.org
# Corey Schafer
# Traversy Media
# CodeWithHarry
# Apna College
# Telusko
# Krish Naik
# Simplilearn

# %%
850 in dataframe
# Out:
# False

# %%
dataframe - 50
# Out:
# Youtuber Name
# Tech With Tim             800
# Programming with Mosh     370
# freeCodeCamp.org         1750
# Corey Schafer             250
# Traversy Media           1150
# CodeWithHarry             900
# Apna College              650
# Telusko                   600
# Krish Naik                850
# Simplilearn              2450
# Name: Total Videos, dtype: int64

# %%
dataframe[dataframe > 500]
# Out:
# Youtuber Name
# Tech With Tim        850
# freeCodeCamp.org    1800
# Traversy Media      1200
# CodeWithHarry        950
# Apna College         700
# Telusko              650
# Krish Naik           900
# Simplilearn         2500
# Name: Total Videos, dtype: int64

# %% [markdown]
# ## Plotting Graphs in pandas
# we require plot function as plot()

# %%
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr"],
    "Sales": [100, 150, 120, 180]
}

df = pd.DataFrame(data)
print(type(df))
print(df)
# df.plot(x="Month", y="Sales")
# Out:
# <class 'pandas.DataFrame'>
#   Month  Sales
# 0   Jan    100
# 1   Feb    150
# 2   Mar    120
# 3   Apr    180

# %%
dataframe.plot

# %%
import matplotlib.pyplot as plt

dataframe.plot()
plt.xticks(rotation=45)
plt.show()

# %%
dataframe
# Out:
# Youtuber Name
# Tech With Tim             850
# Programming with Mosh     420
# freeCodeCamp.org         1800
# Corey Schafer             300
# Traversy Media           1200
# CodeWithHarry             950
# Apna College              700
# Telusko                   650
# Krish Naik                900
# Simplilearn              2500
# Name: Total Videos, dtype: int64

# %%
import matplotlib.pyplot as plt

dataframe.plot(kind="bar", figsize=(12, 6))

plt.xticks(rotation=45, ha="right")
# plt.tight_layout()
plt.show()

# %%
dataframe.plot(kind="barh", figsize=(10, 6))

plt.tight_layout()
plt.show()

# %%
big_df = pd.read_csv("youtube_tech_channels_20251120_133753.csv")

# %%
type(big_df)
# Out:
# pandas.DataFrame

# %%
big_df.shape
# Out:
# (130, 10)

# %%
big_df.columns
# Out:
# Index(['channel_id', 'channel_name', 'description', 'subscribers',
#        'total_views', 'total_videos', 'created_date', 'country',
#        'uploads_playlist', 'scraped_at'],
#       dtype='str')

# %%
big_df.dtypes
# Out:
# channel_id            str
# channel_name          str
# description           str
# subscribers         int64
# total_views         int64
# total_videos        int64
# created_date          str
# country               str
# uploads_playlist      str
# scraped_at            str
# dtype: object

# %%
big_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   channel_id        130 non-null    str
#  1   channel_name      130 non-null    str
#  2   description       127 non-null    str
#  3   subscribers       130 non-null    int64
#  4   total_views       130 non-null    int64
#  5   total_videos      130 non-null    int64
#  6   created_date      130 non-null    str
#  7   country           116 non-null    str
#  8   uploads_playlist  130 non-null    str
#  9   scraped_at        130 non-null    str
# dtypes: int64(3), str(7)
# memory usage: 70.0 KB

# %%
big_df.head(2)
# Out:
#                  channel_id           channel_name  \
# 0  UCXuqSBlHAE6Xw-yeJA0Tunw        Linus Tech Tips
# 1  UCWv7vMbMWH4-V0ZXdmDpPBA  Programming with Mosh
#
#                                          description  subscribers  \
# 0  Linus Tech Tips is a passionate team of "profe...     16600000
# 1  Hi! I'm Mosh 👋, a software engineer with over ...      4860000
#
#    total_views  total_videos          created_date country  \
# 0   9092244390          6989  2008-11-25T00:46:52Z      CA
# 1    257598451           243  2014-10-07T00:40:53Z      US
#
#            uploads_playlist                  scraped_at
# 0  UUXuqSBlHAE6Xw-yeJA0Tunw  2025-11-20T13:37:53.306286
# 1  UUWv7vMbMWH4-V0ZXdmDpPBA  2025-11-20T13:37:53.306286

# %%
big_df.tail(2)
# Out:
#                    channel_id             channel_name  \
# 128  UCTnOFmMwZIi7jJYS_nAfeyQ       The Helpful Hacker
# 129  UCHd1qamEkVSlTWkEqIqJbEQ  Visual Computer Science
#
#                                            description  subscribers  \
# 128  Welcome to The Helpful Hacker! I’m a passionat...        10900
# 129  Welcome to Visual Computer Science! This chann...        10800
#
#      total_views  total_videos                 created_date country  \
# 128       587499            64  2024-06-17T17:08:58.598812Z      US
# 129       839331            35  2020-06-07T09:55:36.218375Z      US
#
#              uploads_playlist                  scraped_at
# 128  UUTnOFmMwZIi7jJYS_nAfeyQ  2025-11-20T13:37:53.306286
# 129  UUHd1qamEkVSlTWkEqIqJbEQ  2025-11-20T13:37:53.306286

# %%
big_df.sample(2)
# Out:
#                    channel_id              channel_name  \
# 83   UC1YoWn9TDojkb9sav-bvykA  whitesec cyber security
# 110  UColtS35pWaswSV634-n-H3A     Everyday Data Science
#
#                                            description  subscribers  \
# 83   Cybersecurity: The Ultimate Challenge in a Dig...        56200
# 110  "Everyday Data Science" is a YouTube channel t...        22400
#
#      total_views  total_videos                 created_date country  \
# 83       1594167            33  2022-11-08T10:07:19.950473Z     NaN
# 110      1913239           623  2021-02-10T06:19:44.698544Z      IN
#
#              uploads_playlist                  scraped_at
# 83   UU1YoWn9TDojkb9sav-bvykA  2025-11-20T13:37:53.306286
# 110  UUoltS35pWaswSV634-n-H3A  2025-11-20T13:37:53.306286

# %%
len(big_df)
# Out:
# 130

# %%
len(big_df.columns)
# Out:
# 10

# %%
big_df.describe()
# Out:
#         subscribers   total_views  total_videos
# count  1.300000e+02  1.300000e+02    130.000000
# mean   5.123438e+05  1.237155e+08    963.769231
# std    1.588629e+06  8.068909e+08   2279.711639
# min    1.080000e+04  2.678500e+04     13.000000
# 25%    3.700000e+04  2.681172e+06    191.250000
# 50%    1.200000e+05  1.059262e+07    374.000000
# 75%    4.120000e+05  3.823083e+07    831.000000
# max    1.660000e+07  9.092244e+09  18375.000000

# %%
big_df.isnull().sum()
# Out:
# channel_id           0
# channel_name         0
# description          3
# subscribers          0
# total_views          0
# total_videos         0
# created_date         0
# country             14
# uploads_playlist     0
# scraped_at           0
# dtype: int64

# %%
big_df.isna().sum()
# Out:
# channel_id           0
# channel_name         0
# description          3
# subscribers          0
# total_views          0
# total_videos         0
# created_date         0
# country             14
# uploads_playlist     0
# scraped_at           0
# dtype: int64

# %%
big_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
big_df.sort_values(by="total_videos", ascending=False).head(5)
# Out:
#                    channel_id          channel_name  \
# 18   UCd6MoB9NC6uYN2grvUNT-Zg   Amazon Web Services
# 22   UCrM7B7SL_g1edFOnmj-SDKg  Bloomberg Technology
# 57   UCdoadna9HFHsxXWhafhNvKw            AWS Events
# 0    UCXuqSBlHAE6Xw-yeJA0Tunw       Linus Tech Tips
# 105  UCCd3-JX7e8uGZx00i5646jg  Daily Tech News Show
#
#                                            description  subscribers  \
# 18   The official YouTube channel for Amazon Web Se...       826000
# 22   Welcome to the Bloomberg Tech YouTube channel....       709000
# 57   The official YouTube channel for AWS Events an...       156000
# 0    Linus Tech Tips is a passionate team of "profe...     16600000
# 105  Welcome to the official YouTube channel of the...        27000
#
#      total_views  total_videos          created_date country  \
# 18     197934117         18375  2009-04-08T23:44:20Z      US
# 22     167411783         13014  2016-09-01T21:38:32Z     NaN
# ...

# %%
big_df[big_df["country"].isin(["IN"])]
# Out:
#                    channel_id                                 channel_name  \
# 20   UC80PWRj_ZU8Zu0HSMNVwKWw                                 Codevolution
# 34   UC9ESQKs98jVWjjUEWkvTMvA                        WsCube Cyber Security
# 36   UCK4ji45I-zxeWXAFKmu3p6Q                                   NetworKing
# 63   UCziVQEj6r60mcsvdeiNbmDw                                    Tech tips
# 69   UCh8IuVJvRdporrHi-I9H7Vw                          Unfold Data Science
# 71   UC1Yf7IBfhSNFTIyb7v83o_g                              AWS with Chetan
# 75   UCbBI_p0ZtBQeDwRdOzPjARw  SoftwareSchool - Coding Tutorials In Telugu
# 76   UCLu_yApfhAgm66qumv4nl4Q                                    Tech Tips
# 84   UCj4b_YT4QnFy6nx3dRCuc1w                     Python Coding (CLCODING)
# 86   UCsBKjqTMwxTVFuJiY33zAAQ                       Cisco Network Learning
# 87   UCuLgfhXLVT7o1EUx8YNwV6A                          Sheryians AI School
# ...

# %%
big_df["country"].value_counts()
# Out:
# country
# US    54
# IN    18
# GB    13
# CA     7
# AU     2
# AE     2
# BR     2
# DE     2
# DK     1
# SG     1
# HR     1
# KE     1
# IE     1
# JP     1
# NO     1
# BG     1
# RU     1
# PH     1
# ID     1
# ES     1
# MT     1
# PK     1
# FI     1
# AT     1
# Name: count, dtype: int64

# %%
big_df.columns
# Out:
# Index(['channel_id', 'channel_name', 'description', 'subscribers',
#        'total_views', 'total_videos', 'created_date', 'country',
#        'uploads_playlist', 'scraped_at'],
#       dtype='str')

# %%
big_df[['channel_name', 'subscribers', 'total_views']].head(5)
# Out:
#             channel_name  subscribers  total_views
# 0        Linus Tech Tips     16600000   9092244390
# 1  Programming with Mosh      4860000    257598451
# 2             TechSource      4010000    870967915
# 3               Bro Code      2990000    178609297
# 4           John Hammond      2080000     82120292

# %%
big_df[
    (big_df["subscribers"] > 1_000_000) &
    (big_df["total_videos"] > 500)
]
# Out:
#                   channel_id               channel_name  \
# 0   UCXuqSBlHAE6Xw-yeJA0Tunw            Linus Tech Tips
# 2   UChIZGfcnjHI0DG4nweWEduw                 TechSource
# 3   UC4SVo0Ue36XCfOyb5Lh1viQ                   Bro Code
# 4   UCVeW9qkBjo3zosnqUbG7CFw               John Hammond
# 5   UCeeFfhMcJa1kjtfZAGskOCA                 TechLinked
# 6   UCvjgXvBlbQiydffZU7m1_aw           The Coding Train
# 7   UCvWWf-LYjaujE50iYai8WgQ            Paul's Hardware
# 9   UCVHFbqXqoYvEWM1Ddxl0QDg         Android Developers
# 11  UCSOpcUkE-is7u7c4AkLgqTw  MrMobile [Michael Fisher]
#
#                                           description  subscribers  \
# 0   Linus Tech Tips is a passionate team of "profe...     16600000
# 2   Join the Discord Server:\nhttps://discord.gg/T...      4010000
# 3                      Coding bootcamps HATE HIM! 🗿\n      2990000
# 4   Free Cybersecurity Education and Ethical Hacking.      2080000
# ...

# %%
big_df.groupby('country').size()
# Out:
# country
# AE     2
# AT     1
# AU     2
# BG     1
# BR     2
# CA     7
# DE     2
# DK     1
# ES     1
# FI     1
# GB    13
# HR     1
# ID     1
# IE     1
# IN    18
# JP     1
# KE     1
# MT     1
# NO     1
# PH     1
# PK     1
# RU     1
# SG     1
# US    54
# dtype: int64

# %%
big_df['country'].value_counts()
# Out:
# country
# US    54
# IN    18
# GB    13
# CA     7
# AU     2
# AE     2
# BR     2
# DE     2
# DK     1
# SG     1
# HR     1
# KE     1
# IE     1
# JP     1
# NO     1
# BG     1
# RU     1
# PH     1
# ID     1
# ES     1
# MT     1
# PK     1
# FI     1
# AT     1
# Name: count, dtype: int64

# %%
big_df.groupby("country")["subscribers"].mean()
# Out:
# country
# AE    1.730000e+05
# AT    2.370000e+04
# AU    1.423000e+05
# BG    3.630000e+05
# BR    6.350000e+04
# CA    2.901457e+06
# DE    4.120000e+04
# DK    1.380000e+06
# ES    9.570000e+04
# FI    3.950000e+04
# GB    2.063231e+05
# HR    1.190000e+06
# ID    1.230000e+05
# IE    5.740000e+05
# IN    1.293500e+05
# JP    5.120000e+05
# KE    9.970000e+05
# MT    8.280000e+04
# NO    4.550000e+05
# PH    1.440000e+05
# PK    4.820000e+04
# RU    1.650000e+05
# SG    1.190000e+06
# US    5.390426e+05
# Name: subscribers, dtype: float64

# %%
big_df.groupby('country')['subscribers'].mean().sort_values()
# Out:
# country
# AT    2.370000e+04
# FI    3.950000e+04
# DE    4.120000e+04
# PK    4.820000e+04
# BR    6.350000e+04
# MT    8.280000e+04
# ES    9.570000e+04
# ID    1.230000e+05
# IN    1.293500e+05
# AU    1.423000e+05
# PH    1.440000e+05
# RU    1.650000e+05
# AE    1.730000e+05
# GB    2.063231e+05
# BG    3.630000e+05
# NO    4.550000e+05
# JP    5.120000e+05
# US    5.390426e+05
# IE    5.740000e+05
# KE    9.970000e+05
# HR    1.190000e+06
# SG    1.190000e+06
# DK    1.380000e+06
# CA    2.901457e+06
# Name: subscribers, dtype: float64

# %%
big_df.groupby("country")["subscribers"].sum()
# Out:
# country
# AE      346000
# AT       23700
# AU      284600
# BG      363000
# BR      127000
# CA    20310200
# DE       82400
# DK     1380000
# ES       95700
# FI       39500
# GB     2682200
# HR     1190000
# ID      123000
# IE      574000
# IN     2328300
# JP      512000
# KE      997000
# MT       82800
# NO      455000
# PH      144000
# PK       48200
# RU      165000
# SG     1190000
# US    29108300
# Name: subscribers, dtype: int64

# %%
big_df.groupby("country")

# %%
big_df.groupby("country")["subscribers"].agg(
    ["count", "mean", "min", "max", "sum"]
).sort_values(by = "sum", ascending = False)
# Out:
#          count          mean      min       max       sum
# country
# US          54  5.390426e+05    10800   4860000  29108300
# CA           7  2.901457e+06    17900  16600000  20310200
# GB          13  2.063231e+05    11000    761000   2682200
# IN          18  1.293500e+05    15100    743000   2328300
# DK           1  1.380000e+06  1380000   1380000   1380000
# HR           1  1.190000e+06  1190000   1190000   1190000
# SG           1  1.190000e+06  1190000   1190000   1190000
# KE           1  9.970000e+05   997000    997000    997000
# IE           1  5.740000e+05   574000    574000    574000
# JP           1  5.120000e+05   512000    512000    512000
# NO           1  4.550000e+05   455000    455000    455000
# BG           1  3.630000e+05   363000    363000    363000
# AE           2  1.730000e+05   154000    192000    346000
# AU           2  1.423000e+05    39600    245000    284600
# RU           1  1.650000e+05   165000    165000    165000
# ...

# %%
big_df.query(
    "subscribers > 1000000 and total_videos > 500"
)
# Out:
#                   channel_id               channel_name  \
# 0   UCXuqSBlHAE6Xw-yeJA0Tunw            Linus Tech Tips
# 2   UChIZGfcnjHI0DG4nweWEduw                 TechSource
# 3   UC4SVo0Ue36XCfOyb5Lh1viQ                   Bro Code
# 4   UCVeW9qkBjo3zosnqUbG7CFw               John Hammond
# 5   UCeeFfhMcJa1kjtfZAGskOCA                 TechLinked
# 6   UCvjgXvBlbQiydffZU7m1_aw           The Coding Train
# 7   UCvWWf-LYjaujE50iYai8WgQ            Paul's Hardware
# 9   UCVHFbqXqoYvEWM1Ddxl0QDg         Android Developers
# 11  UCSOpcUkE-is7u7c4AkLgqTw  MrMobile [Michael Fisher]
#
#                                           description  subscribers  \
# 0   Linus Tech Tips is a passionate team of "profe...     16600000
# 2   Join the Discord Server:\nhttps://discord.gg/T...      4010000
# 3                      Coding bootcamps HATE HIM! 🗿\n      2990000
# 4   Free Cybersecurity Education and Ethical Hacking.      2080000
# ...

# %%
top10 = big_df.sort_values(
    by="subscribers",
    ascending=False
).head(15)

top10.plot(
    x="channel_name",
    y="subscribers",
    kind="barh",
    figsize=(10, 6)
)
# Out:
# <Axes: ylabel='channel_name'>

# %%
top5 = big_df.sort_values(by="total_videos", ascending=False).head(10)
top5.plot(x='channel_name', y='total_videos',kind='barh')
# Out:
# <Axes: ylabel='channel_name'>

# %%
big_df.columns
# Out:
# Index(['channel_id', 'channel_name', 'description', 'subscribers',
#        'total_views', 'total_videos', 'created_date', 'country',
#        'uploads_playlist', 'scraped_at'],
#       dtype='str')

# %%
top15 = big_df.groupby("country")['subscribers'].sum().head(15)
top15.plot(x='subscribers', y='country', kind='barh')
# Out:
# <Axes: ylabel='country'>

# %%
big_df.groupby('country').size()
# Out:
# country
# AE     2
# AT     1
# AU     2
# BG     1
# BR     2
# CA     7
# DE     2
# DK     1
# ES     1
# FI     1
# GB    13
# HR     1
# ID     1
# IE     1
# IN    18
# JP     1
# KE     1
# MT     1
# NO     1
# PH     1
# PK     1
# RU     1
# SG     1
# US    54
# dtype: int64

# %%
big_df['country'].value_counts()
# Out:
# country
# US    54
# IN    18
# GB    13
# CA     7
# AU     2
# AE     2
# BR     2
# DE     2
# DK     1
# SG     1
# HR     1
# KE     1
# IE     1
# JP     1
# NO     1
# BG     1
# RU     1
# PH     1
# ID     1
# ES     1
# MT     1
# PK     1
# FI     1
# AT     1
# Name: count, dtype: int64

# %%
big_df["subscribers"].plot(
    kind="hist",
    bins=30,
    figsize=(10, 6)
)
# Out:
# <Axes: ylabel='Frequency'>

# %%
subs_country_wise = big_df.groupby('country')['subscribers'].mean().sort_values(ascending=False).head(10)
subs_country_wise.plot(kind='bar')
# Out:
# <Axes: xlabel='country'>
